# %% [markdown]
# 在上节课中，我们获取到了想要的数据；这节课中，我们要统计出不同城市的平均薪资与职位数量，将数据进行可视化处理：
#
# 1. 分析网页，找到数据所在网页中的结构；
# 2. 向网页发送请求，获取网页代码；
# 3. 解析网页，提取职位名称、公司名称和所在城市；
# 4. 破解字体反爬虫，提取薪资；
# 5. 统计不同城市的平均薪资与职位数量；
# 6. 绘制柱状图，得出结论。
#
# 今天我们将一边学习，一边完成剩下的步骤。

# %% [markdown]
# 在上节课中，我们把数据全部放在一个名为“职位数据.txt”的文件中。
#
# 要读取 txt 文件中的数据，我们首先需要使用 with...as 语句配合 open() 函数，打开名为“职位数据.txt”的文件。
#
# 在这里，如何将文件中的数据全部读取出来呢。

# %% [markdown]
# # 读取文件所有行

# %% [markdown]
# 打开 txt 文件后，想要读取里面的全部数据，我们可以使用 readlines() 函数。
#
# readlines() 函数可以读取 txt 文件中的所有行并返回一个列表。

# %% [markdown]
# ## readlines()函数

# %% [markdown]
# 要读取 “/Users/tongtong/职位数据.txt” 文件中的所有数据。
#
# 首先，使用 with...as 语句配合 open() 函数以 r 方式，打开文件并赋值给 f。
#
# 使用 readlines() 读取 f 中的所有行，将返回的列表赋值给 dataList。

# %%
# TODO 使用with...as语句配合open()函数以r方式，打开文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # TODO 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# TODO 使用print输出dataList
print(dataList)
# Out:
# ['产品经理,宠物家,北京,100-200/天\n', '产品经理,阿里巴巴,全国,200-300/天\n', '产品经理,网达软件,上海,500-800/天\n', '产品经理,泰康保险集团,北京,120-150/天\n', '业务类产品经理,中石化易捷（成都）国际商贸有限公司,成都,100-200/天\n', '产品经理实习生,青藤云安全,全国,150-180/天\n', '产品经理实习生,时节投资,南京,100-150/天\n', '产品经理实习,乐赴青年,武汉,200-300/天\n', '实习-产品经理,辛巴达智能科技,北京,150-300/天\n', '产品经理实习生,浩鲸科技,广州,150-200/天\n', '产品经理实习生,车300,南京,150-180/天\n', '首席产品经理,蜂鸟矩阵,成都,150-250/天\n', '产品经理实习生,长威科技,福州,120-200/天\n', '产品经理实习生,管易云,上海,180-200/天\n', '产品经理实习生-区块链,得否科技,上海,300-500/天\n', '产品经理实习生,闪捷信息,杭州,150-200/天\n', '产品经理实习生,鹏博士电信传媒集团股份有限公司（北京）,武汉,150-200/天\n', '实习产品经理,MBA中国网,北京,150-200/天\n', '产品经理实习生,云图,宁波,200-400/天\n', '产品经理实习生,上海钢联,上海,150-200/天\n', '产品经理/助理,驰骋控股,衢州,120-200/天\n', '产品经理实习生,薇诺娜,上海,150/天\n', '金融产品经理实习生,浙商国际金融科技（上海）有限公司,上海,300-500/天\n', '职业体验产品经理实习生,探元素,上海,50-100/天\n', '产品实习经理,上海钢联,上海,150-300/天\n', '实习产品经理,新基业,镇江,100-150/天\n', '产品经理实习生,华云科技,杭州,150-200/天\n', '理财顾问（金融产品经理）,麦田房产,北京,300-500/天\n', '产品经理实习生,黑鲨科技,上海,150-180/天\n', '国际支付产品经理实习生,随训通,全国,400-500/天\n', '碳中和事业部-产品经理,翼品资产,上海,200-400/天
# ...

# %% [markdown]
# # 数据提取

# %% [markdown]
# 想要绘制不同城市的平均薪资柱状图，我们先要知道柱状图的 x 轴和 y 轴的数据是什么。
#
# 如图所示，柱状图的 x 轴应该是不同的城市名，y 轴是平均薪资。
#
# 看来，我们需要在列表 dataList 中提取城市和薪资。

# %% [markdown]
# 发现了么，在数据中，有一些薪资不是具体的数字，而是“薪资面议”。
#
# 在这里，如果某一行数据中存在"薪资面议"，就不需要统计他们。
#
# 也就是说，我们可以遍历列表 dataList 的每一项元素，如果"薪资面议"在元素中，就跳过(continue)这个元素。

# %% [markdown]
# 使用 for 循环遍历列表 dataList 中的每个元素，如果"薪资面议"在元素中，使用 continue 跳过这项元素。

# %%
# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# TODO for循环遍历列表dataList中的每个元素data
for data in dataList:

    # TODO 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # TODO 就跳过
        continue

    # TODO 使用print输出元素
    print(data)
# Out:
# 产品经理,宠物家,北京,100-200/天
#
# 产品经理,阿里巴巴,全国,200-300/天
#
# 产品经理,网达软件,上海,500-800/天
#
# 产品经理,泰康保险集团,北京,120-150/天
#
# 业务类产品经理,中石化易捷（成都）国际商贸有限公司,成都,100-200/天
#
# 产品经理实习生,青藤云安全,全国,150-180/天
#
# 产品经理实习生,时节投资,南京,100-150/天
#
# 产品经理实习,乐赴青年,武汉,200-300/天
#
# 实习-产品经理,辛巴达智能科技,北京,150-300/天
#
# 产品经理实习生,浩鲸科技,广州,150-200/天
#
# 产品经理实习生,车300,南京,150-180/天
#
# 首席产品经理,蜂鸟矩阵,成都,150-250/天
#
# 产品经理实习生,长威科技,福州,120-200/天
#
# 产品经理实习生,管易云,上海,180-200/天
#
# 产品经理实习生-区块链,得否科技,上海,300-500/天
#
# 产品经理实习生,闪捷信息,杭州,150-200/天
#
# 产品经理实习生,鹏博士电信传媒集团股份有限公司（北京）,武汉,150-200/天
#
# 实习产品经理,MBA中国网,北京,150-200/天
#
# 产品经理实习生,云图,宁波,200-400/天
#
# 产品经理实习生,上海钢联,上海,150-200/天
#
# 产品经理/助理,驰骋控股,衢州,120-200/天
#
# 产品经理实习生,薇诺娜,上海,150/天
#
# 金融产品经理实习生,浙商国际金融科技（上海）有限公司,上海,300-500/天
#
# 职业体验产品经理实习生,探元素,上海,50-100/天
#
# 产品实习经理,上海钢联,上海,150-300/天
#
# 实习产品经理,新基业,镇江,100-150/天
#
# 产品经理实习生,华云科技,杭州,150-200/天
#
# 理财顾问（金融产品经理）,麦田房产,北京,300-500/天
#
# 产品经理实习生,黑鲨科技,上海,150-180/天
#
# 国际支付产品经理实习生,随训通,全国,400-500/天
#
# 碳中和事业部-产品经理,翼品资产,上海,200-400/天
#
# ...

# %% [markdown]
# ## 分隔字符

# %% [markdown]
# 接着，我们要从列表中提取城市和薪资范围。
#
# 使用 split() 函数以 "," 分隔 data，索引第 3 项元素和第 4 项元素，分别赋值给变量 city和 变量 salary。
#
# 接着使用 split() 函数以 "/" 分隔 salary，索引第 1 项元素，赋值给变量 daily。

# %%
# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# for循环遍历列表dataList中的每项元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # 就跳过
        continue

    # TODO 使用split()以逗号分隔data，索引第3项元素，赋值给city
    city = data.split(",")[2]

    # TODO 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # TODO 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # TODO 使用print使用city
    print(city)

    # TODO 使用print使用daily
    print(daily)
# Out:
# 北京
# 100-200
# 全国
# 200-300
# 上海
# 500-800
# 北京
# 120-150
# 成都
# 100-200
# 全国
# 150-180
# 南京
# 100-150
# 武汉
# 200-300
# 北京
# 150-300
# 广州
# 150-200
# 南京
# 150-180
# 成都
# 150-250
# 福州
# 120-200
# 上海
# 180-200
# 上海
# 300-500
# 杭州
# 150-200
# 武汉
# 150-200
# 北京
# 150-200
# 宁波
# 200-400
# 上海
# 150-200
# 衢州
# 120-200
# 上海
# 150
# 上海
# 300-500
# 上海
# 50-100
# 上海
# 150-300
# 镇江
# 100-150
# 杭州
# 150-200
# 北京
# 300-500
# 上海
# 150-180
# 全国
# 400-500
# 上海
# 200-400
# 北京
# 200-300
# 武汉
# 150-200
# 济南
# 100-200
# 北京
# 180-250
# 北京
# 200-300
# 武汉
# 100-200
# 上海
# 100-180
# 北京
# 200-300
# 北京
# 200-400
# 北京
# 200-250
# 珠海
# 100-180
# 武汉
# 150-300
# 北京
# 250-400
# 北京
# 150-300
# 北京
# 100-200
# 上海
# 200-300
# 北京
# 300-400
# 济南
# 100-200
# 全国
# 100-150
# 全国
# 100-150
# 全国
# 100-150
# 西安
# 150
# 全国
# 100-200
# 北京
# 120-180
# 北京
# 200-250
# 广州
# 200-300
# 南京
# 120-150
# 沈阳
# 0-50
# 沈阳
# 150-200
# 北京
# 120-200
# 北京
# 100-200
# 上海
# 200-250
# 上海
# 150-300
# 深圳
# 120-200
# 上海
# 150-250
# 青岛
# 250-300
# 北京
# ...

# %% [markdown]
# ## 平均薪资

# %% [markdown]
# 现在我们提取出了薪资的范围，但是这样不方便统计，我们可以把这个范围转换成平均薪资。
#
# 比如说以 120-200 为例，以短横线为分隔符，分别提取出 120 和 200。
#
# 由于提取出来的是字符串，需要将 120 和 200 转换成整型，计算它们的平均值也就是相加后在除以2。

# %% [markdown]
# 我们可以使用 split() 函数以 "-" 为分隔符分隔变量 daily，分别索引第1 项和第 2 项，赋值给 start 和 end。
#
# 接着使用 int() 函数将 start 和 end 转换成整型相加后除以2，并赋值给 average。

# %%
# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# for循环遍历列表dataList中的每项元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # 就跳过
        continue

    # 使用split()以逗号分隔data，索引第3项元素，赋值给city
    city = data.split(",")[2]

    # 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # TODO 使用split()以短横线分隔daily索引第1项，赋值给start
    start = daily.split("-")[0]
    # TODO 使用split()以短横线分隔daily索引第2项，赋值给end
    end = daily.split("-")[1]

    # TODO 将start和end转换成整型相加后除以2，并赋值给average
    average = (int(start)+int(end))/2

    # TODO 使用print使用city
    print(city)

    # TODO 使用print使用average
    print(average)
# Out:
# 北京
# 150.0
# 全国
# 250.0
# 上海
# 650.0
# 北京
# 135.0
# 成都
# 150.0
# 全国
# 165.0
# 南京
# 125.0
# 武汉
# 250.0
# 北京
# 225.0
# 广州
# 175.0
# 南京
# 165.0
# 成都
# 200.0
# 福州
# 160.0
# 上海
# 190.0
# 上海
# 400.0
# 杭州
# 175.0
# 武汉
# 175.0
# 北京
# 175.0
# 宁波
# 300.0
# 上海
# 175.0
# 衢州
# 160.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-12d271890873> in <module>
#      25     start = daily.split("-")[0]
#      26     # TODO 使用split()以短横线分隔daily索引第2项，赋值给end
# ---> 27     end = daily.split("-")[1]
#      28
#      29     # TODO 将start和end转换成整型相加后除以2，并赋值给average
#
# IndexError: list index out of range

# %% [markdown]
# # 字典统计

# %% [markdown]
# 现在我们把所在城市与平均薪资都提取出来了，可是有些城市对应的薪资可不止一个。
#
# 接下来，我们要统计不同城市的平均薪资，也就是把同城市对应的薪资相加再除以同城市个数。
#
# 在这里，我们还是可以利用字典来进行统计。

# %% [markdown]
# 在之前的课程中我们使用过字典，将一个键对应一个值。
#
# 在这里，我们可以在字典中让一个键对应多个值，将多个值放在列表中。
#
# 如图所示，在字典 cityDict 中城市作为字典的键，字典的键对应的是一个列表，列表中存储的是同城市对应的不同薪资。

# %% [markdown]
# ## 一键多值

# %% [markdown]
# 在这里，我们在新建一个字典 cityDict。
#
# 判断如果 city 不在字典 cityDict 的键中，就把字典 cityDict 的键对应的值设置为一个空列表。
#
# 接着使用 append() 函数往字典 cityDict 的键对应的值中添加变量 average。

# %%
# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# TODO 新建一个字典cityDict
cityDict = {}

# for循环遍历列表dataList中的每个元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # 就跳过
        continue

    # 使用split()以逗号分隔data，索引第3项元素，赋值给city
    city = data.split(",")[2]

    # 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # 使用split()以短横线分隔daily索引第1项，赋值给start
    start = daily.split("-")[0]
    # 使用split()以短横线分隔daily索引第2项，赋值给end
    end = daily.split("-")[1]

    # 将start和end转换成整型相加后除以2，并赋值给average
    average = (int(start)+int(end))/2

    # TODO 如果city不在字典cityDict的键中
    if city not in cityDict.keys():
      
        # TODO 将字典中键所对应的值设置为空列表
        cityDict[city] = []

    # TODO 使用append()函数往字典键所对应的值中添加average
    cityDict[city].append(average)

# TODO 使用print输出cityDict
print(cityDict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-7bf11d461347> in <module>
#      28     start = daily.split("-")[0]
#      29     # 使用split()以短横线分隔daily索引第2项，赋值给end
# ---> 30     end = daily.split("-")[1]
#      31
#      32     # 将start和end转换成整型相加后除以2，并赋值给average
#
# IndexError: list index out of range

# %% [markdown]
# 我们在字典中使用一键多值，将同城市的不同薪资统计在了列表中，接下来就要计算出同城市的不同薪资。
#
# 在这里，我们可以遍历字典 cityDict 中键和值，计算列表的平均值，再将字典 cityDict 中键对应的值修改为平均值。

# %% [markdown]
# # 字典键对转换

# %% [markdown]
# ## 同时遍历字典的键和值

# %% [markdown]
# 想要遍历字典中的键和值，我们首先可以使用 items() 函数，将字典键对转换成元组数组。
#
# items() 函数把字典中每对 key 和 value 组成一个元组 ，并把这些元组放在列表中返回。

# %%
cityDict = {"合肥": [100.0], "重庆": [160.0, 75.0], "厦门": [100.5], "沈阳": [175.0], "西安": [150.0]}
print(cityDict.items())
# Out:
# dict_items([('合肥', [100.0]), ('重庆', [160.0, 75.0]), ('厦门', [100.5]), ('沈阳', [175.0]), ('西安', [150.0])])

# %% [markdown]
# 将字典键对转换成元组后，我们可以在 for 循环中使用两个参数 key 和 value ，遍历这个由元组组成的列表。
#
# 这样就可以把字典中的键和值分别提取出来。

# %%
cityDict = {"合肥": [100.0], "重庆": [160.0, 75.0], "厦门": [100.5], "沈阳": [175.0], "西安": [150.0]}
for key,value in cityDict.items():
    print(key)
    print(value)
# Out:
# 合肥
# [100.0]
# 重庆
# [160.0, 75.0]
# 厦门
# [100.5]
# 沈阳
# [175.0]
# 西安
# [150.0]

# %% [markdown]
# 由于字典 cityDict 的键对应的值是列表，想要计算出列表的平均值，可以使用 sum() 函数对列表中元素的求和。
#
# 再使用 len() 函数计算列表的长度，接着将列表的和除以列表的长度，就可以列表的平均值。
#
# 然后将字典的键对应的值设置为平均值，这样就得到了不同城市对应的平均薪资。

# %%
cityDict = {"合肥": [100.0], "重庆": [160.0, 75.0], "厦门": [100.5], "沈阳": [175.0], "西安": [150.0]}
for key,value in cityDict.items():
    average_value = sum(value)/len(value)
    cityDict[key] = average_value
print(cityDict)
# Out:
# {'合肥': 100.0, '重庆': 117.5, '厦门': 100.5, '沈阳': 175.0, '西安': 150.0}

# %% [markdown]
# 我们来练习一下，计算字典 cityDict 的键对应的值设置为平均值。
#
# 在这里，我们可以取整运算，使用 "//" 计算平均值。你也也可以试试 "/" 除号，看看运算出的结果有什么不同。

# %%
# 字典cityDict
cityDict = {"合肥": [100.0], "重庆": [160.0, 75.0], "厦门": [100.5], "沈阳": [175.0], "西安": [150.0]}

# TODO for循环遍历cityDict.items()中的key,value
for key, value in cityDict.items():

    # TODO 使用sum()函数将列表value求和
    # 使用len()函数计算列表value长度
    # 使用//运算符计算列表value的平均值，赋值给average_value
    average_value = sum(value)//len(value)

    # TODO 将字典cityDict的键对应的值设置为average_value
    cityDict[key] = average_value

# TODO 使用print输出字典cityDict
print(cityDict)
# Out:
# {'合肥': 100.0, '重庆': 117.0, '厦门': 100.0, '沈阳': 175.0, '西安': 150.0}

# %% [markdown]
# 想要计算出不同城市的平均薪资，我们首先需要使用 for 循环遍历 cityDict.items() 中的 key 和 vaule。
#
# 使用 sum() 函数将列表 value 求和，len() 函数计算列表 value 长度，将列表 value 的和除以列表 value 长度。在这里，我们可以使用 "//" 运算符计算。
#
# 接着将得到的商赋值给变量 average_value。再将字典 cityDict 的键对应的值设置为 average_value。

# %%
# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# 新建一个字典cityDict
cityDict = {}

# for循环遍历列表dataList中的每个元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # 就跳过
        continue

    # 使用split()以逗号分隔data，索引第3项元素，赋值给city
    city = data.split(",")[2]

    # 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # 使用split()以短横线分隔daily索引第1项，赋值给start
    start = daily.split("-")[0]
    # 使用split()以短横线分隔daily索引第2项，赋值给end
    end = daily.split("-")[1]

    # 将start和end转换成整型相加后除以2，并赋值给average
    average = (int(start)+int(end))/2

    # 如果city不在字典cityDict的键中
    if city not in cityDict.keys():
      
        # 将字典中键所对应的值设置为空列表
        cityDict[city] = []

    # 使用append()函数往字典键所对应的值中添加average
    cityDict[city].append(average)

# TODO for循环遍历cityDict.items()中的key,value
for key, value in cityDict.items():

    # TODO 使用sum()函数将列表value求和
    # 使用len()函数计算列表value长度
    # 使用//运算符计算列表value的平均值，赋值给average_value
    average_value = sum(value)//len(value)

    # TODO 将字典cityDict的键对应的值设置为average_value
    cityDict[key] = average_value

# TODO 使用print输出字典cityDict
print(cityDict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-a4a8f0f7718b> in <module>
#      28     start = daily.split("-")[0]
#      29     # 使用split()以短横线分隔daily索引第2项，赋值给end
# ---> 30     end = daily.split("-")[1]
#      31
#      32     # 将start和end转换成整型相加后除以2，并赋值给average
#
# IndexError: list index out of range

# %% [markdown]
# # 绘制柱状图

# %% [markdown]
# 太好了，终于把数据整理好了，接下来，我们就要绘制出柱状图。
#
# 在这里，我们要学习关于绘制柱状图的相关代码。

# %% [markdown]
# 首先，需要从 pyecharts.charts 中导入 Bar 模块。
#
# 接着 Bar() 函数创建一个 Bar 对象，赋值给变量 bar。

# %% [markdown]
# 由于柱状图和我们之前学习过的折线图结构相似，所以它们使用的函数也是类似的。

# %% [markdown]
# 在 add_xaxis() 函数中传入列表，列表中的元素就是柱状图 x 轴的值。
#
# 在这里我们要传入不同城市，可以使用 keys() 函数获取字典中所有的键，在使用 list() 函数将格式转换成列表。
#
# add_yaxis() 函数可以设置柱状图的 y 轴及折线图相关参数。
#
# 第一个参数设置了数据统称，位于柱状图的最上方。
#
# 第二个参数设置了柱状图的 y 轴上的数据，可以使用 values() 函数获取字典中所有的键，在使用 list() 函数将格式转换成列表，接着传入函数中。

# %% [markdown]
# 我们来练习一下吧，首先从 pyecharts.charts 中导入 Bar 模块。
#
# 使用 Bar() 函数创建一个 Bar 对象，赋值给变量 bar；调用 add_xaxis() 函数，将字典 cityDict 所有键转换成列表，传入函数中。
#
# 然后使用 add_yaxis() 函数，传入两个参数，第一个参数将数据统称设置为"各城市薪资"，第二个参数将字典 cityDict 所有值转换成列表。
#
# 接着，使用 render() 函数存储文件，设置文件名为"salary.html"。

# %%
# TODO 从pyecharts.charts中导入Bar模块
from pyecharts.charts import Bar

# 字典cityDict
cityDict = {'合肥': 100.0, '重庆': 117.5, '厦门': 100.5, '沈阳': 175.0, '西安': 150.0}

# TODO 创建Bar对象，赋值给bar
bar = Bar()

# TODO 使用list()将字典cityDict所有键转换成列表，传入add_xaxis()中
bar.add_xaxis(list(cityDict.keys()))

# TODO 使用add_yaxis()函数，将数据统称设置为"各城市薪资"
# 将字典cityDict所有值转换成列表，作为参数添加进函数中
bar.add_yaxis("各城市薪资",list(cityDict.values()))

# TODO 使用render()函数存储文件，设置文件名为salary.html
bar.render("salary_16.html")

from IPython.display import IFrame
IFrame(src='./salary_16.html', width=900, height=500)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
#         <iframe
#             width="900"
#             height="500"
#             src="./salary_16.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# 代码运行成功后，就可以生成柱状图。我们可以一眼看出，沈阳这个城市对应的值最高。
#
# 柱状图可以对一系列数据进行直观的对比，其中一个轴表示需要对比的分类维度，另一个轴代表相应的数值。

# %%
# TODO 从pyecharts.charts中导入Bar模块
from pyecharts.charts import Bar

# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# 新建一个字典cityDict
cityDict = {}

# for循环遍历列表dataList中的每个元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # 就跳过
        continue

    # 使用split()以逗号分隔data，索引第3项元素，赋值给city
    city = data.split(",")[2]

    # 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # 使用split()以短横线分隔daily索引第1项，赋值给start
    start = daily.split("-")[0]
    # 使用split()以短横线分隔daily索引第2项，赋值给end
    end = daily.split("-")[1]

    # 将start和end转换成整型相加后除以2，并赋值给average
    average = (int(start)+int(end))/2

    # 如果city不在字典cityDict的键中
    if city not in cityDict.keys():

        # 将字典中键所对应的值设置为空列表
        cityDict[city] = []

    # 使用append()函数往字典键所对应的值中添加average
    cityDict[city].append(average)

# for循环遍历cityDict.items()中的key,value
for key, value in cityDict.items():

    # 使用sum()函数将列表value求和
    # 使用len()函数计算列表value长度
    # 使用//运算符计算列表value的平均值，赋值给average_value
    average_value = sum(value)//len(value)

    # 将字典cityDict的键对应的值设置为average_value
    cityDict[key] = average_value

# TODO 创建Bar对象，赋值给bar
bar = Bar()

# TODO 使用list()将字典cityDict所有键转换成列表，传入add_xaxis()中
bar.add_xaxis(list(cityDict.keys()))

# TODO 使用add_yaxis()函数，将数据统称设置为"工资平均值"
# 将字典cityDict所有值转换成列表，作为参数添加进函数中
bar.add_yaxis("工资平均值", list(cityDict.values()))

# TODO 使用render()函数存储文件，设置文件名为salary.html
bar.render("salary_16_2.html")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-ba0d96efb716> in <module>
#      31     start = daily.split("-")[0]
#      32     # 使用split()以短横线分隔daily索引第2项，赋值给end
# ---> 33     end = daily.split("-")[1]
#      34
#      35     # 将start和end转换成整型相加后除以2，并赋值给average
#
# IndexError: list index out of range

# %% [markdown]
# 现在我们绘制出不同城市的实习平均薪资柱状图。
#
# 从图中一眼看出，成都的平均薪资是最高的，但是成都产品经理实习职位数量是多少呢？
#
# 看来我们还需要去统计一下不同城市的职位数量。

# %% [markdown]
# # 职位数量

# %% [markdown]
# 我们可以将不同城市作为柱状图的 x 轴，职位数量作为 y 轴。
#
# 职位数量也就是字典 cityDict 的键对应每个列表的长度。
#
# 在这里，我们可以新建一个字典 city_num_dict，将不同城市作为字典 city_num_dict 的键，对应的值设置为列表的长度。

# %%
cityDict = {"合肥": [100.0], "重庆": [160.0, 75.0], "厦门": [100.5], "沈阳": [175.0], "西安": [150.0]}
city_num_dict = {}
for key,value in cityDict.items():
    average_value = sum(value)//len(value)
    cityDict[key] = average_value
    city_num_dict[key] = len(value)
print(city_num_dict)
# Out:
# {'合肥': 1, '重庆': 2, '厦门': 1, '沈阳': 1, '西安': 1}

# %% [markdown]
# 要绘制出不同城市的职位数量，首先新建一个字典 city_num_dict， 在遍历 cityDict.items() 中，将城市作为字典 city_num_dict 的键，将对应的值设置为列表长度。
#
# 接下来，绘制柱状图的代码和之前的是一样的，只是传入的参数值不同。
#
# 把字典 city_num_dict 所有键转换成列表格式，传入柱状图的 x 轴数据；将字典 city_num_dict 所有键对应的值转换成列表格式，传入柱状图的 y 轴数据；
#
# 接着，使用 render() 函数存储文件，设置文件名为"positions.html"。
#
# 注意，在课程里，生成了第一个柱状图后，点击图片以外的任意位置，即可切换第二个柱状图。

# %%
# 从pyecharts.charts中导入Bar模块
from pyecharts.charts import Bar

# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# 新建一个字典cityDict
cityDict = {}

# for循环遍历列表dataList中的每个元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:
        # 就跳过
        continue

    # 使用split()以逗号分隔data，索引第3项元素，赋值给city
    city = data.split(",")[2]

    # 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # 使用split()以短横线分隔daily索引第1项，赋值给start
    start = daily.split("-")[0]
    # 使用split()以短横线分隔daily索引第2项，赋值给end
    end = daily.split("-")[1]

    # 将start和end转换成整型相加后除以2，并赋值给average
    average = (int(start)+int(end))/2

    # 如果city不在字典cityDict的键中
    if city not in cityDict.keys():

        # 将字典中键所对应的值设置为空列表
        cityDict[city] = []

    # 使用append()函数往字典键所对应的值中添加average
    cityDict[city].append(average)

# TODO 新建一个字典city_num_dict
city_num_dict = {}

# for循环遍历cityDict.items()中的key,value
for key,value in cityDict.items():

    # 使用sum()函数将列表value求和
    # 使用len()函数计算列表value长度
    # 使用//运算符计算列表value的平均值，赋值给average_value
    average_value = sum(value)//len(value)

    # 将字典cityDict的键对应的值设置为average_value
    cityDict[key] = average_value

    # TODO 将字典city_num_dict的键设置为不同城市
    # 将对应的值设置为len(value)
    city_num_dict[key] = len(value)

# 创建Bar对象，赋值给bar
bar = Bar()

# 使用list()将字典cityDict所有键转换成列表，传入add_xaxis()中
bar.add_xaxis(list(cityDict.keys()))

# 使用add_yaxis()函数，将数据统称设置为"工资平均值"
# 将字典cityDict所有值转换成列表，作为参数添加进函数中
bar.add_yaxis("工资平均值",list(cityDict.values()))

# 使用render()函数存储文件，设置文件名为salary.html
bar.render("salary_16_3.html")

# TODO 创建Bar对象，赋值给bar_city
bar_city = Bar()

# TODO 使用list()将字典city_num_dict所有键转换成列表，传入add_xaxis()中
bar_city.add_xaxis(list(city_num_dict.keys()))

# TODO 使用add_yaxis()函数，将数据统称设置为"职位数量"
# 将字典city_num_dict所有值转换成列表，作为参数添加进函数中
bar_city.add_yaxis("职位数量",list(city_num_dict.values()))

# TODO 使用render()函数存储文件，设置文件名为positions.html
bar_city.render("positions_16.html")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-4578d666df4f> in <module>
#      31     start = daily.split("-")[0]
#      32     # 使用split()以短横线分隔daily索引第2项，赋值给end
# ---> 33     end = daily.split("-")[1]
#      34
#      35     # 将start和end转换成整型相加后除以2，并赋值给average
#
# IndexError: list index out of range

# %% [markdown]
# 现在我们帮桐桐绘制出了城市平均薪资柱状图和城市职位数量柱状图。
#
# 经过综合考虑，桐桐决定留在成都去夜曲编程实习。

# %% [markdown]
# # 百题斩题目

# %% [markdown]
# ## 二手车均价
# 丁丁想要出售他的二手汽车，于是他在网站上设置了汽车的基本信息--品牌（奔驰），车系（奔驰C级），车龄（1年内），搜索结果一共有4页。
#
# 搜索结果的URL如下所示：
# `f"https://www.che168.com/china/benchi/benchicji/a0_1msdgscncgpi1ltocsp{page}exx0/?pvareaid=102179#currengpostion"`
#
#
# 丁丁想要获取所有车子的价格，最后算出一个平均数，作为自己车子的出售价格，这要怎么实现呢？
#
# 注意哦，这里title的属性值真的是pirce，不是price哦～

# %%
# 使用import导入requests模块
import requests

# 从bs4中导入BeautifulSoup模块
from bs4 import BeautifulSoup

# TODO 创建一个列表price_list
price_list = []

# TODO for循环遍历range()函数生成的1-4的数字
for page in range(1,5):

    # TODO 利用格式化字符生成串网站链接，赋值给变量url
    url = f"https://www.che168.com/china/benchi/benchicji/a0_1msdgscncgpi1ltocsp{page}exx0/?pvareaid=102179#currengpostion"

    # 将User-Agent以字典键对形式赋值给headers
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}

    # TODO 将url和headers参数，添加进requests.get()中，将字典headers传递headers参数，给赋值给response
    response = requests.get(url, headers=headers)

    # TODO 将服务器响应内容转换为字符串形式，赋值给html
    html = response.text

    # TODO 使用BeautifulSoup()传入变量html和解析器lxml，赋值给soup
    soup = BeautifulSoup(html, "lxml")

    # TODO 使用find_all()查询soup中class="pirce"的节点，赋值给content_all
    content_all = soup.find_all(class_="pirce")

    # TODO for循环遍历content_all
    for content in content_all:

        # TODO 使用find()函数，找到<em>标签，并使用.string方法获取字符串，并赋值给price
        price = content.find("em").string

        # TODO 使用float()函数将price转换成浮点型
        # 使用append()添加进price_list
        price_list.append(float(price))
        
# TODO 使用sum()函数将列表price_list求和
# 使用len()函数计算列表price_list长度
# 使用“/”计算平均数赋值给average
average = sum(price_list)/len(price_list)

# TODO 输出average
print(average)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-247aa91e7f71> in <module>
#      37         # TODO 使用float()函数将price转换成浮点型
#      38         # 使用append()添加进price_list
# ---> 39         price_list.append(float(price))
#      40
#      41 # TODO 使用sum()函数将列表price_list求和
#
# TypeError: float() argument must be a string or a number, not 'NoneType'

# %% [markdown]
# ## 就业分析
# 桐桐想要查询不同公司的平均薪资，她从"/Users/tongtong/职位数据.txt"，提取出公司名字与薪资（去掉“薪资面议”的数据），将获得的数据放在字典companyDict中，其键为公司名字，对应的值为公司的平均薪资。
#
# 利用collections中的Counter模块对companyDict中的薪资进行排序，提取其中薪资最高的前7个公司，再利用collections中的OrderedDict模块将数据转换为字典类型。
#
# 最后利用pyecharts.charts中的Bar模块进行数据可视化，绘制出柱状图，如下图所示。
#
# 注意：本题需要用到collections中的Counter模块，OrderedDict模块对字典排序知识点，请点击提示进行学习。

# %% [markdown]
# ```
# …… （省略中间代码）
#
# # 使用Counter()函数统计companyDict中的薪资，赋值给salary_counts
# salary_counts = Counter(companyDict)
#
# # 使用salary_counts.most_common()计算出现频率最高的7个单词，赋值给top_7_company
# top_7_company = salary_counts.most_common(7)
#
# # 使用OrderedDict()函数将top_7_company转换成OrderedDict类型(方便后续使用Bar模块绘制柱状图)，赋值给sorted_companyDict
# sorted_companyDict = OrderedDict(top_7_company)
#
# # 输出sorted_companyDict结果
# print(sorted_companyDict)
# ```
#
#
# 输出结果：
# ```
# OrderedDict([('乐信圣文', 600.0), ('递四方', 600.0), ('猿印', 450.0), ('玉符飞扬', 400.0), ('平安科技', 350.0), ('北京链家', 350.0), ('黯客教育', 300.0)])
# ```

# %%
# 从pyecharts.charts中导入Bar模块
from pyecharts.charts import Bar

# 从collections中导入Counter模块
from collections import Counter

# TODO 从collections中导入OrderedDict模块
from collections import OrderedDict

# 使用with...as语句配合open()函数以r方式，打开路径为“/Users/tongtong/职位数据.txt”的文件，赋值给f
with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_15_output/职位数据.txt", "r") as f:

    # 使用readlines()读取f中的所有行，赋值给dataList
    dataList = f.readlines()

# 新建一个字典cityDict
companyDict = {}

# for循环遍历列表dataList中的每个元素data
for data in dataList:

    # 如果"薪资面议"在元素中
    if "薪资面议" in data:

        # 就跳过
        continue

    # 使用split()以逗号分隔data，索引第2项元素，赋值给company
    company = data.split(",")[1]

    # 使用split()以逗号分隔data，索引第4项元素，赋值给salary
    salary = data.split(",")[3]

    # 使用split()以斜杠分隔salary，索引第1项元素，赋值给daily
    daily = salary.split("/")[0]

    # 使用split()以短横线分隔daily索引第1项，赋值给start
    start = daily.split("-")[0]

    # 使用split()以短横线分隔daily索引第2项，赋值给end
    end = daily.split("-")[1]

    # 将start和end转换成整型相加后除以2，并赋值给average
    average = (int(start)+int(end))/2

    # 如果company不在字典companyDict的键中
    if company not in companyDict.keys():

        # 将字典中键所对应的值设置为空列表
        companyDict[company] = []

    # 使用append()函数往字典键所对应的值中添加average
    companyDict[company].append(average)

# for循环遍历companyDict.items()中的key,value
for key,value in companyDict.items():

    # 使用sum()函数将列表value求和
    # 使用len()函数计算列表value长度
    # 使用//运算符计算列表value的平均值
    average_value = sum(value)//len(value)

    # 将字典companyDict的键对应的值设置为average_value
    companyDict[key] = average_value

# TODO 使用Counter()函数统计companyDict中的薪资，赋值给salary_counts
salary_counts = Counter(companyDict)

# TODO 使用salary_counts.most_common()计算出现频率最高的7个单词，赋值给top_7_company
top_7_company = salary_counts.most_common(7)

# TODO 使用OrderedDict()函数将top_7_company转换成OrderedDict类型，赋值给sorted_companyDict
sorted_companyDict = OrderedDict(top_7_company)

# TODO 创建Bar对象，赋值给bar
bar = Bar()

# TODO 使用list()将字典sorted_companyDict所有键转换成列表，传入add_xaxis()中
bar.add_xaxis(list(sorted_companyDict.keys()))

# TODO 使用add_yaxis()函数，将数据统称设置为"公司"
# 将字典sorted_companyDict所有值转换成列表，作为参数添加进函数中
bar.add_yaxis("公司",list(sorted_companyDict.values()))

# TODO 使用render()函数存储文件，设置文件名为salary.html
bar.render("salary.html")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-e7922ffdba32> in <module>
#      39
#      40     # 使用split()以短横线分隔daily索引第2项，赋值给end
# ---> 41     end = daily.split("-")[1]
#      42
#      43     # 将start和end转换成整型相加后除以2，并赋值给average
#
# IndexError: list index out of range

# %% [markdown]
# ## 前500强
# 桐桐的学姐楠楠，想要跳槽去大公司去做产品经理。
#
# 她在猎聘网上想要选取已经 已上市（在自己电脑上操作时以实际网页上的内容为准）的公司，在这些公司里找到职位名称和职位链接。获取到这些数据，保存在 工作数据.txt 文档中，再来仔细查看岗位JD。
#
# http://nocturne.bczcdn.com/zip/1634267560122_26333/0.html 点击此链接，查看原网页结构。

# %% [markdown]
# User-Agent：
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36
#
# 解题思路：
# 1. 仔细观察前5页网页链接，找出规律，格式化字符串生成 URL 链接；
# 2. 编写代码，请求网页响应，获取前5页网页的源代码；
# 3. 获取每个招聘信息为单元，获取每个单元的节点；
# 4. 从单元节点中获取公司名称、职位名称和职位链接；
# 5. 将获取的数据保存在"/Users/工作数据.txt"文档中。

# %%
# 来，挑战一下
# 请求的url="https://www.liepin.com/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=180&sortFlag=15&degradeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E4%BA%A7%E5%93%81%E7%BB%8F%E7%90%86&siTag=i9Jq-FcUGTpC9QESjC5G3Q%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_fp&d_ckId=61ea6ea3f6d5f5edca49995a72e6c97b&d_curPage=0&d_pageSize=40&d_headId=61ea6ea3f6d5f5edca49995a72e6c97b&curPage=0"
import requests
from bs4 import BeautifulSoup
import time
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}
for i in range(0, 5):
    url = f"https://www.liepin.com/zhaopin/?compkind=&dqs=&pubTime=&pageSize=40&salary=&compTag=180&sortFlag=15&degradeFlag=0&compIds=&subIndustry=&jobKind=&industries=&compscale=&key=%E4%BA%A7%E5%93%81%E7%BB%8F%E7%90%86&siTag=i9Jq-FcUGTpC9QESjC5G3Q%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_fp&d_ckId=61ea6ea3f6d5f5edca49995a72e6c97b&d_curPage=0&d_pageSize=40&d_headId=61ea6ea3f6d5f5edca49995a72e6c97b&curPage={i}"
    response = requests.get(url, headers = headers)
    html = response.text
    soup = BeautifulSoup(html, "lxml")
    titles = soup.find_all(class_ = "sojob-item-main clearfix")
    for item in titles:
        finance = item.find(class_ = "field-financing").find("span").string
        if finance == "已上市":
            name = item.find(class_ = "company-name").find("a").string
            job = item.find("h3").text.strip()
            job_url = item.find("h3").find("a").attrs["href"]
            print(f"{name},{job},{job_url}")
            with open("/Users/xiaojiangyue/programming-study-notes/Python/爬虫/lesson_16_output/工作数据.txt", "a") as f:
                f.write(name+","+job+","+job_url+"\n")
    time.sleep(2)
